# %%
import tweepy
from textblob import TextBlob
import pandas as pd

# %%
customer_key='xEf86l9GcfV5RDwyrs9YT5npz'
customer_secretkey='d9DGumYxGp7Jc8KM5BY1mAS5NVcZswefZWWApnMZlc2dvq6yAP'
access_token='1262425741309784065-KfyDzZlXC58cXsInOGCM45W5eXn0h3'
access_token_secret='BV3wbJnmv1ATmSse4hlFSSjLrdFvFrfXZqKU2JuPytP0a'

auth = tweepy.OAuthHandler(customer_key, customer_secretkey)
auth.set_access_token(access_token, access_token_secret)

api=tweepy.API(auth)
for finding some specific word or content
nepot_tweets=api.search('@nakshatra890', count=1000)

for tweet in nepot_tweets:
     print(tweet.text +'\n')

#for user timeline you can use the other tweet
#nepot_tweets=api.user_timeline(screen_name="@nakshatra890", count=1000, lan='en', tweet_mode='extended')
# Out:
#   File "<ipython-input-602-52102bdb2e76>", line 10
#     for finding some specific word or content
#                    ^
# SyntaxError: invalid syntax

# %%
# ctreating a DataFrame of Tweets.
#df=pd.DataFrame([tweet.text for tweet in nepot_tweets] , columns=['Tweets'])
#df.shape
#df

#for user_time line
df=pd.DataFrame([tweet.full_text for tweet in nepot_tweets] , columns=['Tweets'])
df.shape
df
# Out:
#                                                 Tweets
# 0    In order to discuss the situation in the India...
# 1    Phone call between Prime Minister Shri ⁦@naren...
# 2    लोकल प्रोडक्ट के लिए जिस क्लस्टर बेस्ड रणनीति ...
# 3    किसान के उत्पाद की मार्केटिंग के क्षेत्र में ह...
# 4    हमारे यहां जो smaller factories हैं उन्हें gui...
# ..                                                 ...
# 195  पाँचवाँ पिलर-\nDemand-\n \nहमारी अर्थव्यवस्था ...
# 196  चौथा पिलर-\nहमारी Demography-\n \nदुनिया की सब...
# 197  तीसरा पिलर-\nहमारा System-\n \nएक ऐसा सिस्टम ज...
# 198  आत्मनिर्भर भारत की ये भव्य इमारत,\nपाँच Pillar...
# 199  यही हम भारतीयों की संकल्पशक्ति है।\n \nहम ठान ...
#
# [200 rows x 1 columns]

# %%
# Out:
#                                                Tweets  subjectivity  polarity
# 0   RT @Abhishek1seven: Except #RheaChakraborty th...      0.550000  0.350000
# 1   RT @MayankMewara5: Talent of bollywood childre...      0.000000  0.000000
# 2   RT @prakashraaj: #nepotism  I have lived throu...      0.000000  0.000000
# 3   RT @iArmySupporter: Please don't miss. Careful...      1.000000 -0.100000
# 4   RT @iArmySupporter: Please don't miss. Careful...      1.000000 -0.100000
# 5   RT @RajivRanjanRa16: She told him #MovieMafia....      0.000000  0.000000
# 6   RT @iArmySupporter: Please don't miss. Careful...      1.000000 -0.100000
# 7   Sometimes You Achieve What You Deserves\n\nBut...      0.666667 -0.700000
# 8   RT @iArmySupporter: Please don't miss. Careful...      1.000000 -0.100000
# 9   RT @koenamitra: Shri Krishna said in Mahabhara...      0.333333  0.000000
# 10  Karma strikes hard🙏🏻\n\nMay all those involved...      0.400000  0.100000
# 11  Seriously @DPerwani? Gonna block unfavorable c...      0.522222  0.063889
# 12  @BBCWorld @World @IndiaToday @timesofindia Fig...      0.000000  0.000000
# 13  RT @iArmySupporter: Please don't miss. Careful...      1.000000 -0.100000
# 14  RT @iArmySupporter: Please don't miss. Careful...      1.000000 -0.100000

# %%
#Cleaning the tweets
#In the text of a tweet, there may be some unnecessary symbols which is not essential for our analysis
import re
for i in range(len(df)):
    txt = df.loc[i]["Tweets"]
    txt=re.sub(r'@[A-Z0-9a-z_:]+','',txt)#replace username-tags
    txt=re.sub(r'^[RT]+','',txt)#replace RT-tags
    txt = re.sub('https?://[A-Za-z0-9./]+','',txt)#replace URLs
    txt=re.sub("[^a-zA-Z]", " ",txt)#replace hashtags
    df.at[i,"Tweets"]=txt
    print((df['Tweets']))
df
# Out:
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# ...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
# 0      In order to discuss the situation in the India...
# 1      Phone call between Prime Minister Shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  Demand                          ...
# 196                     Demography                   ...
# 197                      System                      ...
# 198                                           Pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object
#                                                 Tweets  subjectivity  \
# 0    In order to discuss the situation in the India...      0.300000
# 1    Phone call between Prime Minister Shri    and ...      0.000000
# 2                                                  ...      0.000000
# 3                                                  ...      0.000000
# 4                  smaller factories            gui...      0.500000
# ..                                                 ...           ...
# 195                Demand                          ...      0.000000
# 196                   Demography                   ...      0.333333
# 197                    System                      ...      0.000000
# 198                                         Pillars...      0.000000
# 199                                                ...      0.000000
#
#      polarity  Analysis
# 0    0.000000   Neutral
# 1    0.000000   Neutral
# 2    0.000000   Neutral
# 3    0.000000   Neutral
# 4    0.000000   Neutral
# ..        ...       ...
# 195  0.000000   Neutral
# 196  0.166667  Positive
# 197  0.000000   Neutral
# 198  0.000000   Neutral
# 199  0.000000   Neutral
#
# [200 rows x 4 columns]

# %%
#creating a function to get subjectivity 
def get_sub(Tweets):
   return TextBlob(Tweets).sentiment.subjectivity
# creating function for getiing polarity
def get_pol(Tweets):
   return TextBlob(Tweets).sentiment.polarity
df['subjectivity']=df['Tweets'].apply(get_sub)
df['polarity']=df['Tweets'].apply(get_pol)
df
# Out:
#                                                 Tweets  subjectivity  \
# 0    In order to discuss the situation in the India...      0.300000
# 1    Phone call between Prime Minister Shri    and ...      0.000000
# 2                                                  ...      0.000000
# 3                                                  ...      0.000000
# 4                  smaller factories            gui...      0.500000
# ..                                                 ...           ...
# 195                Demand                          ...      0.000000
# 196                   Demography                   ...      0.333333
# 197                    System                      ...      0.000000
# 198                                         Pillars...      0.000000
# 199                                                ...      0.000000
#
#      polarity  Analysis
# 0    0.000000   Neutral
# 1    0.000000   Neutral
# 2    0.000000   Neutral
# 3    0.000000   Neutral
# 4    0.000000   Neutral
# ..        ...       ...
# 195  0.000000   Neutral
# 196  0.166667  Positive
# 197  0.000000   Neutral
# 198  0.000000   Neutral
# 199  0.000000   Neutral
#
# [200 rows x 4 columns]

# %%
df['Tweets'].count()
# Out:
# 200

# %%
df['Tweets'].str.lower()
# Out:
# 0      in order to discuss the situation in the india...
# 1      phone call between prime minister shri    and ...
# 2                                                    ...
# 3                                                    ...
# 4                    smaller factories            gui...
#                              ...
# 195                  demand                          ...
# 196                     demography                   ...
# 197                      system                      ...
# 198                                           pillars...
# 199                                                  ...
# Name: Tweets, Length: 200, dtype: object

# %%
df
# Out:
#                                                 Tweets  subjectivity  \
# 0    In order to discuss the situation in the India...      0.300000
# 1    Phone call between Prime Minister Shri    and ...      0.000000
# 2                                                  ...      0.000000
# 3                                                  ...      0.000000
# 4                  smaller factories            gui...      0.500000
# ..                                                 ...           ...
# 195                Demand                          ...      0.000000
# 196                   Demography                   ...      0.333333
# 197                    System                      ...      0.000000
# 198                                         Pillars...      0.000000
# 199                                                ...      0.000000
#
#      polarity  Analysis
# 0    0.000000   Neutral
# 1    0.000000   Neutral
# 2    0.000000   Neutral
# 3    0.000000   Neutral
# 4    0.000000   Neutral
# ..        ...       ...
# 195  0.000000   Neutral
# 196  0.166667  Positive
# 197  0.000000   Neutral
# 198  0.000000   Neutral
# 199  0.000000   Neutral
#
# [200 rows x 4 columns]

# %%
 #for removing stop words which can affect our data and also may reduce sentiment of tweet.
import nltk
import string as str
from nltk.corpus import stopwords
from pandas import Series,DataFrame
nltk.download('punkt')
nltk.download('stopwords')
from nltk.tokenize import TweetTokenizer

import pandas as pd
import nltk
words=df["Tweets"][0]
stop = stopwords.words('english')
print(stop)

sw_without=df['Tweets'].str.lower().apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)])).str.lower()
sw_without
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]
# 0      order discuss situation india china border are...
# 1      phone call prime minister shri h e prime minis...
# 2                                processing marketing pm
# 3                                                     pm
# 4      smaller factories guidance hand holding trade ...
#                              ...
# 195                                            demand pm
# 196    demography democracy vibrant demography pm aat...
# 197       system technology driven pm aatmanirbharbharat
# 198    pillars economy incremental change quantum jum...
# 199                                pm aatmanirbharbharat
# Name: Tweets, Length: 200, dtype: object

# %%
# creating a world cloud
from matplotlib import pyplot as plt
import numpy
import wordcloud
from wordcloud import WordCloud
sw_without=pd.DataFrame(sw_without)
sw_without

allwords = ' '.join([twts for twts in sw_without['Tweets']])
wordcloud = WordCloud(width=1200,height=900, random_state=100, max_words=100).generate(allwords)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# function to compute negative neutral and positive analysis

def Result(score):
    if score < 0:
        return 'Negative'
    elif score ==0:
        return 'Neutral'
    else:
        return'Positive'
df['Analysis']=df['polarity'].apply(Result)
df['Analysis']
df
# Out:
#                                                 Tweets  subjectivity  \
# 0    In order to discuss the situation in the India...      0.300000
# 1    Phone call between Prime Minister Shri    and ...      0.000000
# 2                                                  ...      0.000000
# 3                                                  ...      0.000000
# 4                  smaller factories            gui...      0.500000
# ..                                                 ...           ...
# 195                Demand                          ...      0.000000
# 196                   Demography                   ...      0.333333
# 197                    System                      ...      0.000000
# 198                                         Pillars...      0.000000
# 199                                                ...      0.000000
#
#      polarity  Analysis
# 0    0.000000   Neutral
# 1    0.000000   Neutral
# 2    0.000000   Neutral
# 3    0.000000   Neutral
# 4    0.000000   Neutral
# ..        ...       ...
# 195  0.000000   Neutral
# 196  0.166667  Positive
# 197  0.000000   Neutral
# 198  0.000000   Neutral
# 199  0.000000   Neutral
#
# [200 rows x 4 columns]

# %%
#print all the positives tweets
neu_df = df[df['Analysis']=="Neutral"]
pos_df = df[df['Analysis']=="Positive"]
neg_df = df[df['Analysis']=="Negative"]
per_neutral = (len(neu_df)/len(df))*100
per_positive = (len(pos_df)/len(df))*100
per_negative = (len(neg_df)/len(df))*100
print (per_negative , per_positive ,per_neutral)

#plotting graph
df['Analysis'].value_counts()

#plot and visualizing
plt.title('Sentimental Analysis')
plt.xlabel('Sentiment')
plt.ylabel('counts')
df["Analysis"].value_counts().plot(kind='bar')
plt.show()
# Out:
# 7.000000000000001 15.5 77.5

# %%
#plotting graph
df['Analysis'].value_counts()

#plot and visualizing
plt.title('Sentimental Analysis')

df["Analysis"].value_counts().plot(kind='pie')
plt.show()

# %%
#### creating graph for polarizaion and sentiment
import numpy
plt.figure(figsize=(8,6))
for i in range(0, df.shape[0]):
    plt.scatter(df['polarity'][i], df['subjectivity'][i], color='Blue')
    
plt.title('Sentimental Analysis')
plt.xlabel('Polarity')
plt.ylabel('Subjectivity')
plt.show()

# %%
per
# Out:
# 74.0
